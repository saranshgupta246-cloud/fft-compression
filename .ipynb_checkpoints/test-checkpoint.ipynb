# %%
import sys; sys.path.append('src')
from fft_core import compress_image_rgb
from utils import load_image, to_pil
from metrics import full_report
import matplotlib.pyplot as plt

img = load_image("assets/sample.jpg")
result = compress_image_rgb(img, keep_fraction=0.1)
report = full_report(img, result, 0.1)
print(report)

fig, ax = plt.subplots(1, 2, figsize=(12,5))
ax[0].imshow(img.astype('uint8')); ax[0].set_title("Original")
ax[1].imshow(result); ax[1].set_title("Compressed")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import sys; sys.path.append('src')
# ----> 2 from fft_core import compress_image_rgb
#       3 from utils import load_image, to_pil
#       4 from metrics import full_report
#
# File c:\Users\saran\fft-compression\src\fft_core.py:1
# ----> 1 import numpy as np
#       2 from PIL import Image
#       4 def apply_fft_2d(channel: np.ndarray) -> np.ndarray:
#
# ModuleNotFoundError: No module named 'numpy'
